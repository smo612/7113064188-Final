# %% [markdown]
# Train

# %%
import gym
from gym import spaces
import numpy as np
import random
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque
import os

save_dir = 'models'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# 使用 GPU 如果可用
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"device:{device}\n")

class IntersectionEnv(gym.Env):
    def __init__(self):
        super(IntersectionEnv, self).__init__()
        
        # 定義觀察空間 (4 張 84x84 圖像)
        self.observation_space = spaces.Box(low=0, high=255, shape=(4, 84, 84), dtype=np.uint8)
        
        # 定義動作空間 (5 種動作：前進、左轉、右轉、剎車、等待)
        self.action_space = spaces.Discrete(5)
        
        # 初始化環境狀態
        self.reset()

    def reset(self):
        # 重置狀態
        self.state = np.zeros((4, 84, 84), dtype=np.uint8)  # 模擬環境圖像
        self.done = False
        self.steps = 0
        self.collisions = 0  # 新增碰撞計數器
        return self.state

    def step(self, action):
        # 更新狀態邏輯 (優化版本)
        self.steps += 1
        reward = -0.1
        
        # 動作與獎勵優化
        if action == 0:  # 前進
            reward = 1
        elif action in [1, 2]:  # 左轉或右轉
            reward = 2
        elif action == 3:  # 剎車
            reward = 0.5
        elif action == 4:  # 等待
            reward = -0.1

        # 增加持續存活獎勵
        reward += 0.1 * self.steps

        # 模擬碰撞或完成檢查 (優化)
        collision_chance = 0.05 if action == 0 else 0.1  # 動態調整碰撞概率
        if random.random() < collision_chance:
            reward = -10
            self.done = True
            self.collisions += 1
        elif self.steps > 50:
            self.done = True

        # 模擬下一張圖像變化
        self.state = np.random.randint(0, 255, (4, 84, 84), dtype=np.uint8)
        
        return self.state, reward, self.done, {}

    def render(self, mode='human'):
        pass

    def close(self):
        pass

# 定義 R2D2 模型
class R2D2(nn.Module):
    def __init__(self, input_shape, n_actions):
        super(R2D2, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(4, 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU()
        )
        self.lstm = nn.LSTM(input_size=64 * 7 * 7, hidden_size=512, batch_first=True)
        self.fc = nn.Linear(512, n_actions)

    def forward(self, x, hidden):
        x = x / 255.0
        x = self.conv(x)
        x = x.view(x.size(0), -1)
        x, hidden = self.lstm(x.unsqueeze(0), hidden)
        return self.fc(x.squeeze(0)), hidden

# 訓練參數優化
BATCH_SIZE = 32
GAMMA = 0.99
EPSILON = 0.1
TARGET_UPDATE = 10
MEMORY_SIZE = 10000
LEARNING_RATE = 1e-4
TAU = 0.005

class PrioritizedReplayBuffer:
    def __init__(self, capacity, alpha=0.6):
        self.buffer = []
        self.capacity = capacity
        self.alpha = alpha
        self.position = 0
        self.priorities = np.zeros((capacity,), dtype=np.float32)

    def push(self, state, action, reward, next_state, done):
        max_prio = self.priorities.max() if len(self.buffer) > 0 else 1.0
        if len(self.buffer) < self.capacity:
            self.buffer.append((state.cpu().numpy(), action, reward, next_state.cpu().numpy(), done))
        else:
            self.buffer[self.position] = (state.cpu().numpy(), action, reward, next_state.cpu().numpy(), done)
        self.priorities[self.position] = max_prio
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size, beta=0.4):
        if len(self.buffer) == self.capacity:
            probs = self.priorities ** self.alpha
            probs /= probs.sum()
        else:
            probs = np.ones(len(self.buffer)) / len(self.buffer)

        indices = np.random.choice(len(self.buffer), batch_size, p=probs)
        samples = [self.buffer[idx] for idx in indices]

        weights = (len(self.buffer) * probs[indices]) ** (-beta)
        weights /= weights.max()
        weights = torch.tensor(weights, dtype=torch.float32).to(device)

        batch = list(zip(*samples))
        states = torch.tensor(np.array(batch[0]), dtype=torch.float32).to(device)
        actions = torch.tensor(batch[1]).to(device)
        rewards = torch.tensor(batch[2], dtype=torch.float32).to(device)
        next_states = torch.tensor(np.array(batch[3]), dtype=torch.float32).to(device)
        dones = torch.tensor(batch[4], dtype=torch.float32).to(device)

        return states, actions, rewards, next_states, dones, weights, indices

    def update_priorities(self, batch_indices, priorities):
        self.priorities[batch_indices] = priorities

    def __len__(self):
        return len(self.buffer)

# 環境與模型初始化
env = IntersectionEnv()
n_actions = env.action_space.n
input_shape = (4, 84, 84)
policy_net = R2D2(input_shape, n_actions).to(device)
target_net = R2D2(input_shape, n_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = optim.Adam(policy_net.parameters(), lr=LEARNING_RATE)
memory = PrioritizedReplayBuffer(MEMORY_SIZE)

best_reward = float('-inf')

# 訓練過程
for episode in range(1000):
    state = env.reset()
    state = torch.tensor(state, dtype=torch.float32).to(device)
    done = False
    total_reward = 0
    epsilon = max(0.01, EPSILON * (0.995 ** episode))
    hidden = (torch.zeros(1, 1, 512).to(device), torch.zeros(1, 1, 512).to(device))
    while not done:
        if random.random() < epsilon:
            action = env.action_space.sample()
        else:
            with torch.no_grad():
                state_tensor = state.unsqueeze(0).to(device)
                q_values, hidden = policy_net(state_tensor, hidden)
                action = q_values.max(1)[1].item()

        next_state, reward, done, _ = env.step(action)
        next_state = torch.tensor(next_state, dtype=torch.float32).to(device)
        memory.push(state, action, reward, next_state, done)
        state = next_state
        total_reward += reward

        if len(memory) > BATCH_SIZE:
            states, actions, rewards, next_states, dones, weights, indices = memory.sample(BATCH_SIZE)

            q_values, _ = policy_net(states, hidden)
            q_values = q_values.gather(1, actions.unsqueeze(1)).squeeze(1)
            next_q_values, _ = target_net(next_states, hidden)
            expected_q_values = rewards + GAMMA * next_q_values.max(1)[0] * (1 - dones)

            losses = nn.MSELoss(reduction='none')(q_values, expected_q_values.detach())
            priorities = losses.detach().cpu().numpy() + 1e-5
            memory.update_priorities(indices, priorities)
            loss = (losses * weights).mean()

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

    if total_reward > best_reward:
        best_reward = total_reward
        torch.save(policy_net.state_dict(), os.path.join(save_dir, 'model.pth'))

    for target_param, param in zip(target_net.parameters(), policy_net.parameters()):
        target_param.data.copy_(TAU * param.data + (1.0 - TAU) * target_param.data)

    print(f"Episode: {episode}, Total Reward: {total_reward}, Epsilon: {epsilon:.3f}")

env.close()
# Out:
# device:cuda
#
# Episode: 0, Total Reward: 6.800000000000001, Epsilon: 0.100
# Episode: 1, Total Reward: 5.800000000000001, Epsilon: 0.100
# Episode: 2, Total Reward: -1.0, Epsilon: 0.099
# Episode: 3, Total Reward: -3.3999999999999995, Epsilon: 0.099
# Episode: 4, Total Reward: -7.9, Epsilon: 0.098
# Episode: 5, Total Reward: 20.3, Epsilon: 0.098
# Episode: 6, Total Reward: 19.400000000000002, Epsilon: 0.097
# Episode: 7, Total Reward: -10, Epsilon: 0.097
# Episode: 8, Total Reward: -5.699999999999999, Epsilon: 0.096
# Episode: 9, Total Reward: -1.0, Epsilon: 0.096
# Episode: 10, Total Reward: 96.39999999999999, Epsilon: 0.095
# Episode: 11, Total Reward: 4.1, Epsilon: 0.095
# Episode: 12, Total Reward: 2.5999999999999996, Epsilon: 0.094
# Episode: 13, Total Reward: 57.0, Epsilon: 0.094
# Episode: 14, Total Reward: 41.800000000000004, Epsilon: 0.093
# Episode: 15, Total Reward: 68.7, Epsilon: 0.093
# Episode: 16, Total Reward: -6.7, Epsilon: 0.092
# Episode: 17, Total Reward: 26.200000000000003, Epsilon: 0.092
# Episode: 18, Total Reward: 77.5, Epsilon: 0.091
# Episode: 19, Total Reward: -6.7, Epsilon: 0.091
# Episode: 20, Total Reward: -10, Epsilon: 0.090
# Episode: 21, Total Reward: 29.0, Epsilon: 0.090
# Episode: 22, Total Reward: 69.0, Epsilon: 0.090
# Episode: 23, Total Reward: 9.600000000000001, Epsilon: 0.089
# Episode: 24, Total Reward: -1.0, Epsilon: 0.089
# Episode: 25, Total Reward: -3.0, Epsilon: 0.088
# Episode: 26, Total Reward: 17.3, Epsilon: 0.088
# Episode: 27, Total Reward: 9.600000000000001, Epsilon: 0.087
# Episode: 28, Total Reward: -1.0, Epsilon: 0.087
# Episode: 29, Total Reward: 2.0999999999999996, Epsilon: 0.086
# Episode: 30, Total Reward: 78.10000000000001, Epsilon: 0.086
# Episode: 31, Total Reward: 83.4, Epsilon: 0.086
# Episode: 32, Total Reward: 74.7, Epsilon: 0.085
# Episode: 33, Total Reward: -7.9, Epsilon: 0.085
# Episode: 34, Total Reward: 10.600000000000001, Epsilon: 0.084
# Episode: 35, Total Reward: -5.699999999999999, Epsilon: 0.084
# Episode: 36, Total Reward: 0.6999999999999993, Epsilon: 0.083
# Episode: 37, Total Reward: -5.699999999999999, Epsilon: 0.083
# Episode: 38, Total Reward: -7.9, Epsilon: 0.083
# Episode: 39, Total Reward: 68.0, Epsilon: 0.082
# Episode: 40, Total Reward: 13.600000000000001, Epsilon: 0.082
# Episode: 41, Total Reward: 4.1, Epsilon: 0.081
# Episode: 42, Total Reward: -1.0, Epsilon: 0.081
# Episode: 43, Total Reward: -10, Epsilon: 0.081
# Episode: 44, Total Reward: -5.9, Epsilon: 0.080
# Episode: 45, Total Reward: 19.5, Epsilon: 0.080
# Episode: 46, Total Reward: 43.5, Epsilon: 0.079
# Episode: 47, Total Reward: -10, Epsilon: 0.079
# Episode: 48, Total Reward: -5.699999999999999, Epsilon: 0.079
# Episode: 49, Total Reward: 65.2, Epsilon: 0.078
# Episode: 50, Total Reward: -10, Epsilon: 0.078
# Episode: 51, Total Reward: -4.0, Epsilon: 0.077
# Episode: 52, Total Reward: -7.7, Epsilon: 0.077
# Episode: 53, Total Reward: -10, Epsilon: 0.077
# Episode: 54, Total Reward: -1.0, Epsilon: 0.076
# Episode: 55, Total Reward: -0.5, Epsilon: 0.076
# Episode: 56, Total Reward: -10, Epsilon: 0.076
# Episode: 57, Total Reward: -3.3999999999999995, Epsilon: 0.075
# Episode: 58, Total Reward: -10, Epsilon: 0.075
# Episode: 59, Total Reward: -10, Epsilon: 0.074
# Episode: 60, Total Reward: -10, Epsilon: 0.074
# Episode: 61, Total Reward: 3.8000000000000007, Epsilon: 0.074
# Episode: 62, Total Reward: 21.5, Epsilon: 0.073
# Episode: 63, Total Reward: 45.1, Epsilon: 0.073
# Episode: 64, Total Reward: 1.3000000000000007, Epsilon: 0.073
# Episode: 65, Total Reward: -4.4, Epsilon: 0.072
# Episode: 66, Total Reward: 1.5, Epsilon: 0.072
# Episode: 67, Total Reward: 91.30000000000001, Epsilon: 0.071
# Episode: 68, Total Reward: -5.699999999999999, Epsilon: 0.071
# Episode: 69, Total Reward: -10, Epsilon: 0.071
# Episode: 70, Total Reward: 217.60000000000002, Epsilon: 0.070
# Episode: 71, Total Reward: 13.600000000000001, Epsilon: 0.070
# Episode: 72, Total Reward: 17.7, Epsilon: 0.070
# Episode: 73, Total Reward: 1.5999999999999996, Epsilon: 0.069
# Episode: 74, Total Reward: 35.1, Epsilon: 0.069
# Episode: 75, Total Reward: 8.5, Epsilon: 0.069
# Episode: 76, Total Reward: 14.100000000000001, Epsilon: 0.068
# Episode: 77, Total Reward: -7.9, Epsilon: 0.068
# Episode: 78, Total Reward: -0.10000000000000142, Epsilon: 0.068
# Episode: 79, Total Reward: -4.3999999999999995, Epsilon: 0.067
# Episode: 80, Total Reward: -10, Epsilon: 0.067
# Episode: 81, Total Reward: 27.5, Epsilon: 0.067
# Episode: 82, Total Reward: -6.7, Epsilon: 0.066
# Episode: 83, Total Reward: -5.699999999999999, Epsilon: 0.066
# Episode: 84, Total Reward: -10, Epsilon: 0.066
# Episode: 85, Total Reward: -10, Epsilon: 0.065
# Episode: 86, Total Reward: -0.5, Epsilon: 0.065
# Episode: 87, Total Reward: -4.6, Epsilon: 0.065
# Episode: 88, Total Reward: -5.699999999999999, Epsilon: 0.064
# Episode: 89, Total Reward: 5.100000000000001, Epsilon: 0.064
# Episode: 90, Total Reward: -3.3999999999999995, Epsilon: 0.064
# Episode: 91, Total Reward: 7.5, Epsilon: 0.063
# Episode: 92, Total Reward: -4.5, Epsilon: 0.063
# Episode: 93, Total Reward: 3.3000000000000007, Epsilon: 0.063
# Episode: 94, Total Reward: 56.000000000000014, Epsilon: 0.062
# Episode: 95, Total Reward: 128.7, Epsilon: 0.062
# Episode: 96, Total Reward: -5.4, Epsilon: 0.062
# Episode: 97, Total Reward: -10, Epsilon: 0.061
# Episode: 98, Total Reward: -3.0, Epsilon: 0.061
# Episode: 99, Total Reward: -7.9, Epsilon: 0.061
# Episode: 100, Total Reward: 1.0999999999999996, Epsilon: 0.061
# Episode: 101, Total Reward: 21.700000000000003, Epsilon: 0.060
# Episode: 102, Total Reward: -10, Epsilon: 0.060
# Episode: 103, Total Reward: 29.000000000000007, Epsilon: 0.060
# Episode: 104, Total Reward: -5.699999999999999, Epsilon: 0.059
# Episode: 105, Total Reward: 19.6, Epsilon: 0.059
# Episode: 106, Total Reward: -0.5999999999999996, Epsilon: 0.059
# Episode: 107, Total Reward: 60.400000000000006, Epsilon: 0.058
# Episode: 108, Total Reward: -4.4, Epsilon: 0.058
# Episode: 109, Total Reward: 19.800000000000004, Epsilon: 0.058
# Episode: 110, Total Reward: 12.5, Epsilon: 0.058
# Episode: 111, Total Reward: -5.699999999999999, Epsilon: 0.057
# Episode: 112, Total Reward: 81.9, Epsilon: 0.057
# Episode: 113, Total Reward: 7.100000000000001, Epsilon: 0.057
# Episode: 114, Total Reward: -4.3999999999999995, Epsilon: 0.056
# Episode: 115, Total Reward: 13.5, Epsilon: 0.056
# Episode: 116, Total Reward: -1.5, Epsilon: 0.056
# Episode: 117, Total Reward: 57.000000000000014, Epsilon: 0.056
# Episode: 118, Total Reward: -7.9, Epsilon: 0.055
# Episode: 119, Total Reward: 9.5, Epsilon: 0.055
# Episode: 120, Total Reward: 181.00000000000003, Epsilon: 0.055
# Episode: 121, Total Reward: -7.9, Epsilon: 0.055
# Episode: 122, Total Reward: -7.2, Epsilon: 0.054
# Episode: 123, Total Reward: 67.8, Epsilon: 0.054
# Episode: 124, Total Reward: 10.5, Epsilon: 0.054
# Episode: 125, Total Reward: -3.0999999999999996, Epsilon: 0.053
# Episode: 126, Total Reward: -10, Epsilon: 0.053
# Episode: 127, Total Reward: 74.10000000000001, Epsilon: 0.053
# Episode: 128, Total Reward: -4.3999999999999995, Epsilon: 0.053
# Episode: 129, Total Reward: -4.3999999999999995, Epsilon: 0.052
# Episode: 130, Total Reward: 74.7, Epsilon: 0.052
# Episode: 131, Total Reward: 17.3, Epsilon: 0.052
# Episode: 132, Total Reward: -0.5, Epsilon: 0.052
# Episode: 133, Total Reward: -4.5, Epsilon: 0.051
# Episode: 134, Total Reward: 18.199999999999996, Epsilon: 0.051
# Episode: 135, Total Reward: 140.5, Epsilon: 0.051
# Episode: 136, Total Reward: 78.4, Epsilon: 0.051
# Episode: 137, Total Reward: -7.9, Epsilon: 0.050
# Episode: 138, Total Reward: 35.4, Epsilon: 0.050
# Episode: 139, Total Reward: -5.699999999999999, Epsilon: 0.050
# Episode: 140, Total Reward: -4.4, Epsilon: 0.050
# Episode: 141, Total Reward: -7.2, Epsilon: 0.049
# Episode: 142, Total Reward: -10, Epsilon: 0.049
# Episode: 143, Total Reward: 144.7, Epsilon: 0.049
# Episode: 144, Total Reward: 9.0, Epsilon: 0.049
# Episode: 145, Total Reward: 20.4, Epsilon: 0.048
# Episode: 146, Total Reward: -4.3999999999999995, Epsilon: 0.048
# Episode: 147, Total Reward: 42.5, Epsilon: 0.048
# Episode: 148, Total Reward: 12.600000000000001, Epsilon: 0.048
# Episode: 149, Total Reward: -7.9, Epsilon: 0.047
# Episode: 150, Total Reward: -6.7, Epsilon: 0.047
# Episode: 151, Total Reward: -5.699999999999999, Epsilon: 0.047
# Episode: 152, Total Reward: 6.600000000000001, Epsilon: 0.047
# Episode: 153, Total Reward: -10, Epsilon: 0.046
# Episode: 154, Total Reward: -10, Epsilon: 0.046
# Episode: 155, Total Reward: 71.80000000000001, Epsilon: 0.046
# Episode: 156, Total Reward: 19.4, Epsilon: 0.046
# Episode: 157, Total Reward: 20.4, Epsilon: 0.046
# Episode: 158, Total Reward: 32.300000000000004, Epsilon: 0.045
# Episode: 159, Total Reward: 81.9, Epsilon: 0.045
# Episode: 160, Total Reward: -1.5, Epsilon: 0.045
# Episode: 161, Total Reward: -7.2, Epsilon: 0.045
# Episode: 162, Total Reward: -7.9, Epsilon: 0.044
# Episode: 163, Total Reward: -10, Epsilon: 0.044
# Episode: 164, Total Reward: 8.5, Epsilon: 0.044
# Episode: 165, Total Reward: 1.3000000000000007, Epsilon: 0.044
# Episode: 166, Total Reward: 21.0, Epsilon: 0.044
# Episode: 167, Total Reward: 23.400000000000006, Epsilon: 0.043
# Episode: 168, Total Reward: 15.400000000000002, Epsilon: 0.043
# Episode: 169, Total Reward: -10, Epsilon: 0.043
# Episode: 170, Total Reward: -10, Epsilon: 0.043
# Episode: 171, Total Reward: -10, Epsilon: 0.042
# Episode: 172, Total Reward: 77.4, Epsilon: 0.042
# Episode: 173, Total Reward: 102.00000000000001, Epsilon: 0.042
# Episode: 174, Total Reward: 25.400000000000006, Epsilon: 0.042
# Episode: 175, Total Reward: -6.7, Epsilon: 0.042
# Episode: 176, Total Reward: 2.0999999999999996, Epsilon: 0.041
# Episode: 177, Total Reward: 9.5, Epsilon: 0.041
# Episode: 178, Total Reward: -5.699999999999999, Epsilon: 0.041
# Episode: 179, Total Reward: -4.3999999999999995, Epsilon: 0.041
# Episode: 180, Total Reward: -10, Epsilon: 0.041
# Episode: 181, Total Reward: -7.9, Epsilon: 0.040
# Episode: 182, Total Reward: -7.9, Epsilon: 0.040
# Episode: 183, Total Reward: 28.6, Epsilon: 0.040
# Episode: 184, Total Reward: -0.5, Epsilon: 0.040
# Episode: 185, Total Reward: 14.100000000000001, Epsilon: 0.040
# Episode: 186, Total Reward: 56.80000000000001, Epsilon: 0.039
# Episode: 187, Total Reward: -7.9, Epsilon: 0.039
# Episode: 188, Total Reward: 7.0, Epsilon: 0.039
# Episode: 189, Total Reward: -4.9, Epsilon: 0.039
# Episode: 190, Total Reward: -7.9, Epsilon: 0.039
# Episode: 191, Total Reward: 114.7, Epsilon: 0.038
# Episode: 192, Total Reward: 43.1, Epsilon: 0.038
# Episode: 193, Total Reward: 12.600000000000001, Epsilon: 0.038
# Episode: 194, Total Reward: 141.8, Epsilon: 0.038
# Episode: 195, Total Reward: 0.0, Epsilon: 0.038
# Episode: 196, Total Reward: 4.800000000000001, Epsilon: 0.037
# Episode: 197, Total Reward: 2.8000000000000007, Epsilon: 0.037
# Episode: 198, Total Reward: 1.3000000000000007, Epsilon: 0.037
# Episode: 199, Total Reward: 14.100000000000001, Epsilon: 0.037
# Episode: 200, Total Reward: -6.7, Epsilon: 0.037
# Episode: 201, Total Reward: 11.5, Epsilon: 0.037
# Episode: 202, Total Reward: -2.5, Epsilon: 0.036
# Episode: 203, Total Reward: 106.0, Epsilon: 0.036
# Episode: 204, Total Reward: 4.1, Epsilon: 0.036
# Episode: 205, Total Reward: 41.5, Epsilon: 0.036
# Episode: 206, Total Reward: 7.5, Epsilon: 0.036
# Episode: 207, Total Reward: -7.9, Epsilon: 0.035
# Episode: 208, Total Reward: 18.6, Epsilon: 0.035
# Episode: 209, Total Reward: 120.1, Epsilon: 0.035
# Episode: 210, Total Reward: -10, Epsilon: 0.035
# Episode: 211, Total Reward: 91.39999999999999, Epsilon: 0.035
# Episode: 212, Total Reward: -7.8, Epsilon: 0.035
# Episode: 213, Total Reward: 59.000000000000014, Epsilon: 0.034
# Episode: 214, Total Reward: -2.0, Epsilon: 0.034
# Episode: 215, Total Reward: -10, Epsilon: 0.034
# Episode: 216, Total Reward: 53.50000000000001, Epsilon: 0.034
# Episode: 217, Total Reward: 11.600000000000001, Epsilon: 0.034
# Episode: 218, Total Reward: -10, Epsilon: 0.034
# Episode: 219, Total Reward: 8.600000000000001, Epsilon: 0.033
# Episode: 220, Total Reward: 33.6, Epsilon: 0.033
# Episode: 221, Total Reward: 0.0, Epsilon: 0.033
# Episode: 222, Total Reward: 2.8000000000000007, Epsilon: 0.033
# Episode: 223, Total Reward: 12.0, Epsilon: 0.033
# Episode: 224, Total Reward: 118.29999999999998, Epsilon: 0.033
# Episode: 225, Total Reward: -7.9, Epsilon: 0.032
# Episode: 226, Total Reward: -6.7, Epsilon: 0.032
# Episode: 227, Total Reward: -7.9, Epsilon: 0.032
# Episode: 228, Total Reward: -3.3999999999999995, Epsilon: 0.032
# Episode: 229, Total Reward: -5.699999999999999, Epsilon: 0.032
# Episode: 230, Total Reward: 36.5, Epsilon: 0.032
# Episode: 231, Total Reward: -6.7, Epsilon: 0.031
# Episode: 232, Total Reward: 8.100000000000001, Epsilon: 0.031
# Episode: 233, Total Reward: 16.6, Epsilon: 0.031
# Episode: 234, Total Reward: 14.600000000000001, Epsilon: 0.031
# Episode: 235, Total Reward: 1.8000000000000007, Epsilon: 0.031
# Episode: 236, Total Reward: 37.0, Epsilon: 0.031
# Episode: 237, Total Reward: -5.9, Epsilon: 0.030
# Episode: 238, Total Reward: -5.699999999999999, Epsilon: 0.030
# Episode: 239, Total Reward: -7.9, Epsilon: 0.030
# Episode: 240, Total Reward: 60.000000000000014, Epsilon: 0.030
# Episode: 241, Total Reward: 30.800000000000004, Epsilon: 0.030
# Episode: 242, Total Reward: -3.3999999999999995, Epsilon: 0.030
# Episode: 243, Total Reward: -10, Epsilon: 0.030
# Episode: 244, Total Reward: -2.0, Epsilon: 0.029
# Episode: 245, Total Reward: 34.2, Epsilon: 0.029
# Episode: 246, Total Reward: 12.5, Epsilon: 0.029
# Episode: 247, Total Reward: 14.8, Epsilon: 0.029
# Episode: 248, Total Reward: -7.9, Epsilon: 0.029
# Episode: 249, Total Reward: -5.699999999999999, Epsilon: 0.029
# Episode: 250, Total Reward: 11.0, Epsilon: 0.029
# Episode: 251, Total Reward: -6.7, Epsilon: 0.028
# Episode: 252, Total Reward: -6.1000000000000005, Epsilon: 0.028
# Episode: 253, Total Reward: 46.2, Epsilon: 0.028
# Episode: 254, Total Reward: 7.5, Epsilon: 0.028
# Episode: 255, Total Reward: -7.9, Epsilon: 0.028
# Episode: 256, Total Reward: 3.0999999999999996, Epsilon: 0.028
# Episode: 257, Total Reward: -7.9, Epsilon: 0.028
# Episode: 258, Total Reward: 2.0999999999999996, Epsilon: 0.027
# Episode: 259, Total Reward: -6.9, Epsilon: 0.027
# Episode: 260, Total Reward: 29.200000000000003, Epsilon: 0.027
# Episode: 261, Total Reward: 0.5, Epsilon: 0.027
# Episode: 262, Total Reward: -3.0999999999999996, Epsilon: 0.027
# Episode: 263, Total Reward: 39.400000000000006, Epsilon: 0.027
# Episode: 264, Total Reward: -7.9, Epsilon: 0.027
# Episode: 265, Total Reward: 62.400000000000006, Epsilon: 0.026
# Episode: 266, Total Reward: -3.5, Epsilon: 0.026
# Episode: 267, Total Reward: 41.0, Epsilon: 0.026
# Episode: 268, Total Reward: 90.20000000000002, Epsilon: 0.026
# Episode: 269, Total Reward: -7.9, Epsilon: 0.026
# Episode: 270, Total Reward: -7.2, Epsilon: 0.026
# Episode: 271, Total Reward: 0.5999999999999996, Epsilon: 0.026
# Episode: 272, Total Reward: 11.000000000000004, Epsilon: 0.026
# Episode: 273, Total Reward: -5.699999999999999, Epsilon: 0.025
# Episode: 274, Total Reward: 66.6, Epsilon: 0.025
# Episode: 275, Total Reward: 2.3000000000000007, Epsilon: 0.025
# Episode: 276, Total Reward: 122.60000000000002, Epsilon: 0.025
# Episode: 277, Total Reward: -7.9, Epsilon: 0.025
# Episode: 278, Total Reward: 7.100000000000001, Epsilon: 0.025
# Episode: 279, Total Reward: 1.3000000000000007, Epsilon: 0.025
# Episode: 280, Total Reward: 41.9, Epsilon: 0.025
# Episode: 281, Total Reward: -6.1, Epsilon: 0.024
# Episode: 282, Total Reward: 6.800000000000001, Epsilon: 0.024
# Episode: 283, Total Reward: -7.2, Epsilon: 0.024
# Episode: 284, Total Reward: -10, Epsilon: 0.024
# Episode: 285, Total Reward: -3.3999999999999995, Epsilon: 0.024
# Episode: 286, Total Reward: -7.9, Epsilon: 0.024
# Episode: 287, Total Reward: 7.100000000000001, Epsilon: 0.024
# Episode: 288, Total Reward: -3.0, Epsilon: 0.024
# Episode: 289, Total Reward: 24.0, Epsilon: 0.023
# Episode: 290, Total Reward: -7.9, Epsilon: 0.023
# Episode: 291, Total Reward: 7.900000000000002, Epsilon: 0.023
# Episode: 292, Total Reward: 68.10000000000001, Epsilon: 0.023
# Episode: 293, Total Reward: 15.3, Epsilon: 0.023
# Episode: 294, Total Reward: -5.699999999999999, Epsilon: 0.023
# Episode: 295, Total Reward: 10.500000000000004, Epsilon: 0.023
# Episode: 296, Total Reward: 29.1, Epsilon: 0.023
# Episode: 297, Total Reward: 7.5, Epsilon: 0.023
# Episode: 298, Total Reward: 20.4, Epsilon: 0.022
# Episode: 299, Total Reward: 6.600000000000001, Epsilon: 0.022
# Episode: 300, Total Reward: -10, Epsilon: 0.022
# Episode: 301, Total Reward: -7.2, Epsilon: 0.022
# Episode: 302, Total Reward: -3.0, Epsilon: 0.022
# Episode: 303, Total Reward: 2.0999999999999996, Epsilon: 0.022
# Episode: 304, Total Reward: -7.9, Epsilon: 0.022
# Episode: 305, Total Reward: -10, Epsilon: 0.022
# Episode: 306, Total Reward: -7.9, Epsilon: 0.022
# Episode: 307, Total Reward: -1.0, Epsilon: 0.021
# Episode: 308, Total Reward: 170.2, Epsilon: 0.021
# Episode: 309, Total Reward: 12.600000000000001, Epsilon: 0.021
# Episode: 310, Total Reward: 63.000000000000014, Epsilon: 0.021
# Episode: 311, Total Reward: -3.5, Epsilon: 0.021
# Episode: 312, Total Reward: 18.1, Epsilon: 0.021
# Episode: 313, Total Reward: 32.00000000000001, Epsilon: 0.021
# Episode: 314, Total Reward: -5.699999999999999, Epsilon: 0.021
# Episode: 315, Total Reward: 3.5, Epsilon: 0.021
# Episode: 316, Total Reward: -10, Epsilon: 0.021
# Episode: 317, Total Reward: -7.9, Epsilon: 0.020
# Episode: 318, Total Reward: -10, Epsilon: 0.020
# Episode: 319, Total Reward: 4.800000000000001, Epsilon: 0.020
# Episode: 320, Total Reward: -7.9, Epsilon: 0.020
# Episode: 321, Total Reward: -2.0, Epsilon: 0.020
# Episode: 322, Total Reward: -7.9, Epsilon: 0.020
# Episode: 323, Total Reward: 9.0, Epsilon: 0.020
# Episode: 324, Total Reward: -6.7, Epsilon: 0.020
# Episode: 325, Total Reward: 139.29999999999998, Epsilon: 0.020
# Episode: 326, Total Reward: -10, Epsilon: 0.020
# Episode: 327, Total Reward: -7.9, Epsilon: 0.019
# Episode: 328, Total Reward: 1.5999999999999996, Epsilon: 0.019
# Episode: 329, Total Reward: 19.1, Epsilon: 0.019
# Episode: 330, Total Reward: -7.9, Epsilon: 0.019
# Episode: 331, Total Reward: 14.600000000000001, Epsilon: 0.019
# Episode: 332, Total Reward: -3.0999999999999996, Epsilon: 0.019
# Episode: 333, Total Reward: 9.399999999999999, Epsilon: 0.019
# Episode: 334, Total Reward: 30.0, Epsilon: 0.019
# Episode: 335, Total Reward: -5.499999999999999, Epsilon: 0.019
# Episode: 336, Total Reward: -1.0, Epsilon: 0.019
# Episode: 337, Total Reward: -10, Epsilon: 0.018
# Episode: 338, Total Reward: -10, Epsilon: 0.018
# Episode: 339, Total Reward: -7.2, Epsilon: 0.018
# Episode: 340, Total Reward: 4.100000000000001, Epsilon: 0.018
# Episode: 341, Total Reward: -7.2, Epsilon: 0.018
# Episode: 342, Total Reward: -7.9, Epsilon: 0.018
# Episode: 343, Total Reward: -10, Epsilon: 0.018
# Episode: 344, Total Reward: 15.100000000000001, Epsilon: 0.018
# Episode: 345, Total Reward: -10, Epsilon: 0.018
# Episode: 346, Total Reward: -4.0, Epsilon: 0.018
# Episode: 347, Total Reward: -10, Epsilon: 0.018
# Episode: 348, Total Reward: 37.5, Epsilon: 0.017
# Episode: 349, Total Reward: -7.9, Epsilon: 0.017
# Episode: 350, Total Reward: 11.5, Epsilon: 0.017
# Episode: 351, Total Reward: 67.4, Epsilon: 0.017
# Episode: 352, Total Reward: -4.3999999999999995, Epsilon: 0.017
# Episode: 353, Total Reward: 29.700000000000003, Epsilon: 0.017
# Episode: 354, Total Reward: -5.699999999999999, Epsilon: 0.017
# Episode: 355, Total Reward: 35.0, Epsilon: 0.017
# Episode: 356, Total Reward: 67.7, Epsilon: 0.017
# Episode: 357, Total Reward: -0.5, Epsilon: 0.017
# Episode: 358, Total Reward: 29.9, Epsilon: 0.017
# Episode: 359, Total Reward: 20.9, Epsilon: 0.017
# Episode: 360, Total Reward: -10, Epsilon: 0.016
# Episode: 361, Total Reward: 136.1, Epsilon: 0.016
# Episode: 362, Total Reward: -3.0, Epsilon: 0.016
# Episode: 363, Total Reward: 18.1, Epsilon: 0.016
# Episode: 364, Total Reward: 23.5, Epsilon: 0.016
# Episode: 365, Total Reward: 93.5, Epsilon: 0.016
# Episode: 366, Total Reward: -8.6, Epsilon: 0.016
# Episode: 367, Total Reward: 26.700000000000003, Epsilon: 0.016
# Episode: 368, Total Reward: 0.5, Epsilon: 0.016
# Episode: 369, Total Reward: -3.0, Epsilon: 0.016
# Episode: 370, Total Reward: 19.6, Epsilon: 0.016
# Episode: 371, Total Reward: -8.9, Epsilon: 0.016
# Episode: 372, Total Reward: 44.0, Epsilon: 0.015
# Episode: 373, Total Reward: 26.6, Epsilon: 0.015
# Episode: 374, Total Reward: 148.7, Epsilon: 0.015
# Episode: 375, Total Reward: 8.899999999999999, Epsilon: 0.015
# Episode: 376, Total Reward: 98.40000000000002, Epsilon: 0.015
# Episode: 377, Total Reward: 2.5999999999999996, Epsilon: 0.015
# Episode: 378, Total Reward: -7.9, Epsilon: 0.015
# Episode: 379, Total Reward: 102.9, Epsilon: 0.015
# Episode: 380, Total Reward: 2.8000000000000007, Epsilon: 0.015
# Episode: 381, Total Reward: -7.2, Epsilon: 0.015
# Episode: 382, Total Reward: 4.0, Epsilon: 0.015
# Episode: 383, Total Reward: -5.5, Epsilon: 0.015
# Episode: 384, Total Reward: 3.0, Epsilon: 0.015
# Episode: 385, Total Reward: 33.1, Epsilon: 0.015
# Episode: 386, Total Reward: 16.6, Epsilon: 0.014
# Episode: 387, Total Reward: 56.900000000000006, Epsilon: 0.014
# Episode: 388, Total Reward: 163.1, Epsilon: 0.014
# Episode: 389, Total Reward: 35.5, Epsilon: 0.014
# Episode: 390, Total Reward: 1.5, Epsilon: 0.014
# Episode: 391, Total Reward: 1.0999999999999996, Epsilon: 0.014
# Episode: 392, Total Reward: 1.0999999999999996, Epsilon: 0.014
# Episode: 393, Total Reward: -3.3999999999999995, Epsilon: 0.014
# Episode: 394, Total Reward: 1.0999999999999996, Epsilon: 0.014
# Episode: 395, Total Reward: 201.4, Epsilon: 0.014
# Episode: 396, Total Reward: 18.900000000000006, Epsilon: 0.014
# Episode: 397, Total Reward: 96.9, Epsilon: 0.014
# Episode: 398, Total Reward: -3.3999999999999995, Epsilon: 0.014
# Episode: 399, Total Reward: 7.0, Epsilon: 0.014
# Episode: 400, Total Reward: -10, Epsilon: 0.013
# Episode: 401, Total Reward: 5.800000000000001, Epsilon: 0.013
# Episode: 402, Total Reward: 11.5, Epsilon: 0.013
# Episode: 403, Total Reward: 5.100000000000001, Epsilon: 0.013
# Episode: 404, Total Reward: 28.6, Epsilon: 0.013
# Episode: 405, Total Reward: 1.5999999999999996, Epsilon: 0.013
# Episode: 406, Total Reward: 12.2, Epsilon: 0.013
# Episode: 407, Total Reward: 0.5999999999999996, Epsilon: 0.013
# Episode: 408, Total Reward: -7.9, Epsilon: 0.013
# Episode: 409, Total Reward: 35.8, Epsilon: 0.013
# Episode: 410, Total Reward: -8.9, Epsilon: 0.013
# Episode: 411, Total Reward: -2.5, Epsilon: 0.013
# Episode: 412, Total Reward: 3.0, Epsilon: 0.013
# Episode: 413, Total Reward: 4.100000000000001, Epsilon: 0.013
# Episode: 414, Total Reward: -1.3999999999999986, Epsilon: 0.013
# Episode: 415, Total Reward: -7.9, Epsilon: 0.012
# Episode: 416, Total Reward: 29.6, Epsilon: 0.012
# Episode: 417, Total Reward: 10.5, Epsilon: 0.012
# Episode: 418, Total Reward: 20.0, Epsilon: 0.012
# Episode: 419, Total Reward: -2.0, Epsilon: 0.012
# Episode: 420, Total Reward: 59.500000000000014, Epsilon: 0.012
# Episode: 421, Total Reward: -10, Epsilon: 0.012
# Episode: 422, Total Reward: -1.3000000000000007, Epsilon: 0.012
# Episode: 423, Total Reward: 183.0, Epsilon: 0.012
# Episode: 424, Total Reward: -3.0999999999999996, Epsilon: 0.012
# Episode: 425, Total Reward: -2.0999999999999996, Epsilon: 0.012
# Episode: 426, Total Reward: 10.600000000000001, Epsilon: 0.012
# Episode: 427, Total Reward: 44.300000000000004, Epsilon: 0.012
# Episode: 428, Total Reward: -5.699999999999999, Epsilon: 0.012
# Episode: 429, Total Reward: 2.3000000000000007, Epsilon: 0.012
# Episode: 430, Total Reward: -4.3999999999999995, Epsilon: 0.012
# Episode: 431, Total Reward: 18.6, Epsilon: 0.012
# Episode: 432, Total Reward: 27.5, Epsilon: 0.011
# Episode: 433, Total Reward: 36.1, Epsilon: 0.011
# Episode: 434, Total Reward: 1.5999999999999996, Epsilon: 0.011
# Episode: 435, Total Reward: -10, Epsilon: 0.011
# Episode: 436, Total Reward: 9.5, Epsilon: 0.011
# Episode: 437, Total Reward: 47.2, Epsilon: 0.011
# Episode: 438, Total Reward: -1.5, Epsilon: 0.011
# Episode: 439, Total Reward: 31.1, Epsilon: 0.011
# Episode: 440, Total Reward: -7.2, Epsilon: 0.011
# Episode: 441, Total Reward: -10, Epsilon: 0.011
# Episode: 442, Total Reward: -3.0, Epsilon: 0.011
# Episode: 443, Total Reward: 37.400000000000006, Epsilon: 0.011
# Episode: 444, Total Reward: 25.5, Epsilon: 0.011
# Episode: 445, Total Reward: -0.5, Epsilon: 0.011
# Episode: 446, Total Reward: 2.6999999999999993, Epsilon: 0.011
# Episode: 447, Total Reward: -7.2, Epsilon: 0.011
# Episode: 448, Total Reward: 6.5, Epsilon: 0.011
# Episode: 449, Total Reward: -10, Epsilon: 0.011
# Episode: 450, Total Reward: -6.7, Epsilon: 0.010
# Episode: 451, Total Reward: 16.8, Epsilon: 0.010
# Episode: 452, Total Reward: 22.5, Epsilon: 0.010
# Episode: 453, Total Reward: -10, Epsilon: 0.010
# Episode: 454, Total Reward: 58.900000000000006, Epsilon: 0.010
# Episode: 455, Total Reward: -7.9, Epsilon: 0.010
# Episode: 456, Total Reward: 8.5, Epsilon: 0.010
# Episode: 457, Total Reward: 5.600000000000001, Epsilon: 0.010
# Episode: 458, Total Reward: 42.0, Epsilon: 0.010
# Episode: 459, Total Reward: 36.8, Epsilon: 0.010
# Episode: 460, Total Reward: -10, Epsilon: 0.010
# Episode: 461, Total Reward: 38.4, Epsilon: 0.010
# Episode: 462, Total Reward: 213.0, Epsilon: 0.010
# Episode: 463, Total Reward: -2.0, Epsilon: 0.010
# Episode: 464, Total Reward: 31.300000000000004, Epsilon: 0.010
# Episode: 465, Total Reward: -1.5, Epsilon: 0.010
# Episode: 466, Total Reward: -10, Epsilon: 0.010
# Episode: 467, Total Reward: 3.3000000000000007, Epsilon: 0.010
# Episode: 468, Total Reward: 88.00000000000001, Epsilon: 0.010
# Episode: 469, Total Reward: 96.69999999999999, Epsilon: 0.010
# Episode: 470, Total Reward: 10.5, Epsilon: 0.010
# Episode: 471, Total Reward: -2.5, Epsilon: 0.010
# Episode: 472, Total Reward: 46.70000000000001, Epsilon: 0.010
# Episode: 473, Total Reward: 13.100000000000001, Epsilon: 0.010
# Episode: 474, Total Reward: 7.899999999999999, Epsilon: 0.010
# Episode: 475, Total Reward: 22.0, Epsilon: 0.010
# Episode: 476, Total Reward: 18.6, Epsilon: 0.010
# Episode: 477, Total Reward: -6.699999999999999, Epsilon: 0.010
# Episode: 478, Total Reward: 9.0, Epsilon: 0.010
# Episode: 479, Total Reward: 12.000000000000004, Epsilon: 0.010
# Episode: 480, Total Reward: -10, Epsilon: 0.010
# Episode: 481, Total Reward: 74.3, Epsilon: 0.010
# Episode: 482, Total Reward: -10, Epsilon: 0.010
# Episode: 483, Total Reward: 38.900000000000006, Epsilon: 0.010
# Episode: 484, Total Reward: 43.0, Epsilon: 0.010
# Episode: 485, Total Reward: 7.5, Epsilon: 0.010
# Episode: 486, Total Reward: -10, Epsilon: 0.010
# Episode: 487, Total Reward: 17.9, Epsilon: 0.010
# Episode: 488, Total Reward: 97.9, Epsilon: 0.010
# Episode: 489, Total Reward: -7.9, Epsilon: 0.010
# Episode: 490, Total Reward: -7.9, Epsilon: 0.010
# Episode: 491, Total Reward: 52.60000000000001, Epsilon: 0.010
# Episode: 492, Total Reward: 154.5, Epsilon: 0.010
# Episode: 493, Total Reward: 26.0, Epsilon: 0.010
# Episode: 494, Total Reward: 9.899999999999999, Epsilon: 0.010
# Episode: 495, Total Reward: -10, Epsilon: 0.010
# Episode: 496, Total Reward: 19.5, Epsilon: 0.010
# Episode: 497, Total Reward: -7.9, Epsilon: 0.010
# Episode: 498, Total Reward: -10, Epsilon: 0.010
# Episode: 499, Total Reward: 2.1000000000000014, Epsilon: 0.010
# Episode: 500, Total Reward: -4.9, Epsilon: 0.010
# Episode: 501, Total Reward: -3.3999999999999995, Epsilon: 0.010
# Episode: 502, Total Reward: -4.0, Epsilon: 0.010
# Episode: 503, Total Reward: 15.3, Epsilon: 0.010
# Episode: 504, Total Reward: -7.9, Epsilon: 0.010
# Episode: 505, Total Reward: 16.6, Epsilon: 0.010
# Episode: 506, Total Reward: 3.0999999999999996, Epsilon: 0.010
# Episode: 507, Total Reward: 1.5999999999999996, Epsilon: 0.010
# Episode: 508, Total Reward: 30.700000000000003, Epsilon: 0.010
# Episode: 509, Total Reward: -7.2, Epsilon: 0.010
# Episode: 510, Total Reward: -7.9, Epsilon: 0.010
# Episode: 511, Total Reward: 210.5, Epsilon: 0.010
# Episode: 512, Total Reward: -7.9, Epsilon: 0.010
# Episode: 513, Total Reward: -7.9, Epsilon: 0.010
# Episode: 514, Total Reward: -3.3999999999999995, Epsilon: 0.010
# Episode: 515, Total Reward: 2.6999999999999993, Epsilon: 0.010
# Episode: 516, Total Reward: 0.5, Epsilon: 0.010
# Episode: 517, Total Reward: 136.60000000000002, Epsilon: 0.010
# Episode: 518, Total Reward: 84.0, Epsilon: 0.010
# Episode: 519, Total Reward: 77.0, Epsilon: 0.010
# Episode: 520, Total Reward: 29.400000000000006, Epsilon: 0.010
# Episode: 521, Total Reward: -10, Epsilon: 0.010
# Episode: 522, Total Reward: 0.5, Epsilon: 0.010
# Episode: 523, Total Reward: -7.9, Epsilon: 0.010
# Episode: 524, Total Reward: 4.600000000000001, Epsilon: 0.010
# Episode: 525, Total Reward: 18.6, Epsilon: 0.010
# Episode: 526, Total Reward: 35.300000000000004, Epsilon: 0.010
# Episode: 527, Total Reward: -3.5, Epsilon: 0.010
# Episode: 528, Total Reward: 3.8000000000000007, Epsilon: 0.010
# Episode: 529, Total Reward: 75.8, Epsilon: 0.010
# Episode: 530, Total Reward: -2.0, Epsilon: 0.010
# Episode: 531, Total Reward: 33.1, Epsilon: 0.010
# Episode: 532, Total Reward: 89.3, Epsilon: 0.010
# Episode: 533, Total Reward: -10, Epsilon: 0.010
# Episode: 534, Total Reward: -10, Epsilon: 0.010
# Episode: 535, Total Reward: 46.5, Epsilon: 0.010
# Episode: 536, Total Reward: 12.0, Epsilon: 0.010
# Episode: 537, Total Reward: -7.8, Epsilon: 0.010
# Episode: 538, Total Reward: -3.3999999999999995, Epsilon: 0.010
# Episode: 539, Total Reward: -6.7, Epsilon: 0.010
# Episode: 540, Total Reward: -7.9, Epsilon: 0.010
# Episode: 541, Total Reward: -3.5, Epsilon: 0.010
# Episode: 542, Total Reward: -6.7, Epsilon: 0.010
# Episode: 543, Total Reward: 5.100000000000001, Epsilon: 0.010
# Episode: 544, Total Reward: 0.5, Epsilon: 0.010
# Episode: 545, Total Reward: 56.500000000000014, Epsilon: 0.010
# Episode: 546, Total Reward: 2.0999999999999996, Epsilon: 0.010
# Episode: 547, Total Reward: 10.0, Epsilon: 0.010
# Episode: 548, Total Reward: -7.9, Epsilon: 0.010
# Episode: 549, Total Reward: 55.5, Epsilon: 0.010
# Episode: 550, Total Reward: 12.5, Epsilon: 0.010
# Episode: 551, Total Reward: 33.800000000000004, Epsilon: 0.010
# Episode: 552, Total Reward: -6.7, Epsilon: 0.010
# Episode: 553, Total Reward: 7.899999999999999, Epsilon: 0.010
# Episode: 554, Total Reward: 48.6, Epsilon: 0.010
# Episode: 555, Total Reward: -2.5, Epsilon: 0.010
# Episode: 556, Total Reward: -6.7, Epsilon: 0.010
# Episode: 557, Total Reward: -7.9, Epsilon: 0.010
# Episode: 558, Total Reward: -10, Epsilon: 0.010
# Episode: 559, Total Reward: 28.6, Epsilon: 0.010
# Episode: 560, Total Reward: 0.5, Epsilon: 0.010
# Episode: 561, Total Reward: 16.8, Epsilon: 0.010
# Episode: 562, Total Reward: 20.299999999999997, Epsilon: 0.010
# Episode: 563, Total Reward: -3.3999999999999995, Epsilon: 0.010
# Episode: 564, Total Reward: 10.899999999999999, Epsilon: 0.010
# Episode: 565, Total Reward: 0.5999999999999996, Epsilon: 0.010
# Episode: 566, Total Reward: 10.5, Epsilon: 0.010
# Episode: 567, Total Reward: -0.5, Epsilon: 0.010
# Episode: 568, Total Reward: 0.5, Epsilon: 0.010
# Episode: 569, Total Reward: 27.0, Epsilon: 0.010
# Episode: 570, Total Reward: 5.5, Epsilon: 0.010
# Episode: 571, Total Reward: -2.0, Epsilon: 0.010
# Episode: 572, Total Reward: -7.9, Epsilon: 0.010
# Episode: 573, Total Reward: -10, Epsilon: 0.010
# Episode: 574, Total Reward: 6.0, Epsilon: 0.010
# Episode: 575, Total Reward: -2.0, Epsilon: 0.010
# Episode: 576, Total Reward: -4.9, Epsilon: 0.010
# Episode: 577, Total Reward: -5.9, Epsilon: 0.010
# Episode: 578, Total Reward: 4.100000000000001, Epsilon: 0.010
# Episode: 579, Total Reward: 22.799999999999997, Epsilon: 0.010
# Episode: 580, Total Reward: 55.400000000000006, Epsilon: 0.010
# Episode: 581, Total Reward: -7.9, Epsilon: 0.010
# Episode: 582, Total Reward: -7.9, Epsilon: 0.010
# Episode: 583, Total Reward: 6.200000000000003, Epsilon: 0.010
# Episode: 584, Total Reward: 15.100000000000001, Epsilon: 0.010
# Episode: 585, Total Reward: -10, Epsilon: 0.010
# Episode: 586, Total Reward: 14.8, Epsilon: 0.010
# Episode: 587, Total Reward: -4.5, Epsilon: 0.010
# Episode: 588, Total Reward: -4.1000000000000005, Epsilon: 0.010
# Episode: 589, Total Reward: 55.5, Epsilon: 0.010
# Episode: 590, Total Reward: 54.60000000000001, Epsilon: 0.010
# Episode: 591, Total Reward: 6.5, Epsilon: 0.010
# Episode: 592, Total Reward: -5.699999999999999, Epsilon: 0.010
# Episode: 593, Total Reward: 17.8, Epsilon: 0.010
# Episode: 594, Total Reward: 9.600000000000001, Epsilon: 0.010
# Episode: 595, Total Reward: -10, Epsilon: 0.010
# Episode: 596, Total Reward: -5.699999999999999, Epsilon: 0.010
# Episode: 597, Total Reward: 4.300000000000001, Epsilon: 0.010
# Episode: 598, Total Reward: -4.8999999999999995, Epsilon: 0.010
# Episode: 599, Total Reward: -10, Epsilon: 0.010
# Episode: 600, Total Reward: -4.1000000000000005, Epsilon: 0.010
# Episode: 601, Total Reward: -6.7, Epsilon: 0.010
# Episode: 602, Total Reward: 70.0, Epsilon: 0.010
# Episode: 603, Total Reward: -7.9, Epsilon: 0.010
# Episode: 604, Total Reward: -6.7, Epsilon: 0.010
# Episode: 605, Total Reward: 62.60000000000001, Epsilon: 0.010
# Episode: 606, Total Reward: 12.399999999999999, Epsilon: 0.010
# Episode: 607, Total Reward: 16.0, Epsilon: 0.010
# Episode: 608, Total Reward: -4.8999999999999995, Epsilon: 0.010
# Episode: 609, Total Reward: 46.300000000000004, Epsilon: 0.010
# Episode: 610, Total Reward: 12.500000000000004, Epsilon: 0.010
# Episode: 611, Total Reward: 3.8000000000000007, Epsilon: 0.010
# Episode: 612, Total Reward: -10, Epsilon: 0.010
# Episode: 613, Total Reward: -2.0, Epsilon: 0.010
# Episode: 614, Total Reward: 17.1, Epsilon: 0.010
# Episode: 615, Total Reward: 49.1, Epsilon: 0.010
# Episode: 616, Total Reward: 11.600000000000001, Epsilon: 0.010
# Episode: 617, Total Reward: 30.300000000000004, Epsilon: 0.010
# Episode: 618, Total Reward: 21.8, Epsilon: 0.010
# Episode: 619, Total Reward: -4.8999999999999995, Epsilon: 0.010
# Episode: 620, Total Reward: 6.400000000000002, Epsilon: 0.010
# Episode: 621, Total Reward: 203.4, Epsilon: 0.010
# Episode: 622, Total Reward: -10, Epsilon: 0.010
# Episode: 623, Total Reward: 26.4, Epsilon: 0.010
# Episode: 624, Total Reward: -7.9, Epsilon: 0.010
# Episode: 625, Total Reward: 1.0999999999999996, Epsilon: 0.010
# Episode: 626, Total Reward: 41.1, Epsilon: 0.010
# Episode: 627, Total Reward: 34.1, Epsilon: 0.010
# Episode: 628, Total Reward: 3.6999999999999993, Epsilon: 0.010
# Episode: 629, Total Reward: -10, Epsilon: 0.010
# Episode: 630, Total Reward: 31.800000000000004, Epsilon: 0.010
# Episode: 631, Total Reward: 10.100000000000001, Epsilon: 0.010
# Episode: 632, Total Reward: 1.0999999999999996, Epsilon: 0.010
# Episode: 633, Total Reward: 210.50000000000003, Epsilon: 0.010
# Episode: 634, Total Reward: -7.9, Epsilon: 0.010
# Episode: 635, Total Reward: 45.1, Epsilon: 0.010
# Episode: 636, Total Reward: -10, Epsilon: 0.010
# Episode: 637, Total Reward: -6.7, Epsilon: 0.010
# Episode: 638, Total Reward: 21.6, Epsilon: 0.010
# Episode: 639, Total Reward: 2.8000000000000007, Epsilon: 0.010
# Episode: 640, Total Reward: 8.5, Epsilon: 0.010
# Episode: 641, Total Reward: 6.800000000000001, Epsilon: 0.010
# Episode: 642, Total Reward: 1.5, Epsilon: 0.010
# Episode: 643, Total Reward: 7.800000000000001, Epsilon: 0.010
# Episode: 644, Total Reward: 34.4, Epsilon: 0.010
# Episode: 645, Total Reward: 14.7, Epsilon: 0.010
# Episode: 646, Total Reward: 4.300000000000001, Epsilon: 0.010
# Episode: 647, Total Reward: 8.600000000000001, Epsilon: 0.010
# Episode: 648, Total Reward: 205.79999999999998, Epsilon: 0.010
# Episode: 649, Total Reward: 71.89999999999999, Epsilon: 0.010
# Episode: 650, Total Reward: -7.8, Epsilon: 0.010
# Episode: 651, Total Reward: 22.9, Epsilon: 0.010
# Episode: 652, Total Reward: -7.9, Epsilon: 0.010
# Episode: 653, Total Reward: -7.9, Epsilon: 0.010
# Episode: 654, Total Reward: 3.0999999999999996, Epsilon: 0.010
# Episode: 655, Total Reward: -3.3999999999999995, Epsilon: 0.010
# Episode: 656, Total Reward: 75.00000000000001, Epsilon: 0.010
# Episode: 657, Total Reward: 5.100000000000001, Epsilon: 0.010
# Episode: 658, Total Reward: 6.399999999999999, Epsilon: 0.010
# Episode: 659, Total Reward: 15.0, Epsilon: 0.010
# Episode: 660, Total Reward: 60.599999999999994, Epsilon: 0.010
# Episode: 661, Total Reward: -10, Epsilon: 0.010
# Episode: 662, Total Reward: 35.4, Epsilon: 0.010
# Episode: 663, Total Reward: 20.300000000000004, Epsilon: 0.010
# Episode: 664, Total Reward: -5.5, Epsilon: 0.010
# Episode: 665, Total Reward: -5.699999999999999, Epsilon: 0.010
# Episode: 666, Total Reward: -10, Epsilon: 0.010
# Episode: 667, Total Reward: -3.5, Epsilon: 0.010
# Episode: 668, Total Reward: -7.9, Epsilon: 0.010
# Episode: 669, Total Reward: 15.600000000000001, Epsilon: 0.010
# Episode: 670, Total Reward: -3.0, Epsilon: 0.010
# Episode: 671, Total Reward: 13.099999999999998, Epsilon: 0.010
# Episode: 672, Total Reward: -3.999999999999999, Epsilon: 0.010
# Episode: 673, Total Reward: -10, Epsilon: 0.010
# Episode: 674, Total Reward: -7.8, Epsilon: 0.010
# Episode: 675, Total Reward: 9.399999999999999, Epsilon: 0.010
# Episode: 676, Total Reward: -10, Epsilon: 0.010
# Episode: 677, Total Reward: -7.9, Epsilon: 0.010
# Episode: 678, Total Reward: -4.9, Epsilon: 0.010
# Episode: 679, Total Reward: -2.0, Epsilon: 0.010
# Episode: 680, Total Reward: 163.4, Epsilon: 0.010
# Episode: 681, Total Reward: -1.0, Epsilon: 0.010
# Episode: 682, Total Reward: 8.5, Epsilon: 0.010
# Episode: 683, Total Reward: 12.000000000000004, Epsilon: 0.010
# Episode: 684, Total Reward: 168.7, Epsilon: 0.010
# Episode: 685, Total Reward: -6.7, Epsilon: 0.010
# Episode: 686, Total Reward: -2.0, Epsilon: 0.010
# Episode: 687, Total Reward: 3.5, Epsilon: 0.010
# Episode: 688, Total Reward: 74.6, Epsilon: 0.010
# Episode: 689, Total Reward: 18.5, Epsilon: 0.010
# Episode: 690, Total Reward: 2.1999999999999993, Epsilon: 0.010
# Episode: 691, Total Reward: 23.4, Epsilon: 0.010
# Episode: 692, Total Reward: -5.699999999999999, Epsilon: 0.010
# Episode: 693, Total Reward: 30.900000000000006, Epsilon: 0.010
# Episode: 694, Total Reward: 6.600000000000001, Epsilon: 0.010
# Episode: 695, Total Reward: 8.0, Epsilon: 0.010
# Episode: 696, Total Reward: 36.5, Epsilon: 0.010
# Episode: 697, Total Reward: 71.6, Epsilon: 0.010
# Episode: 698, Total Reward: 2.3000000000000007, Epsilon: 0.010
# Episode: 699, Total Reward: 0.5, Epsilon: 0.010
# Episode: 700, Total Reward: -7.9, Epsilon: 0.010
# Episode: 701, Total Reward: 23.0, Epsilon: 0.010
# Episode: 702, Total Reward: 9.0, Epsilon: 0.010
# Episode: 703, Total Reward: -10, Epsilon: 0.010
# Episode: 704, Total Reward: 3.8000000000000007, Epsilon: 0.010
# Episode: 705, Total Reward: -1.0, Epsilon: 0.010
# Episode: 706, Total Reward: -3.3999999999999995, Epsilon: 0.010
# Episode: 707, Total Reward: 40.9, Epsilon: 0.010
# Episode: 708, Total Reward: -5.9, Epsilon: 0.010
# Episode: 709, Total Reward: -10, Epsilon: 0.010
# Episode: 710, Total Reward: 26.0, Epsilon: 0.010
# Episode: 711, Total Reward: 18.1, Epsilon: 0.010
# Episode: 712, Total Reward: 36.5, Epsilon: 0.010
# Episode: 713, Total Reward: -5.4, Epsilon: 0.010
# Episode: 714, Total Reward: 153.9, Epsilon: 0.010
# Episode: 715, Total Reward: 1.0999999999999996, Epsilon: 0.010
# Episode: 716, Total Reward: -4.9, Epsilon: 0.010
# Episode: 717, Total Reward: -7.8, Epsilon: 0.010
# Episode: 718, Total Reward: 38.00000000000001, Epsilon: 0.010
# Episode: 719, Total Reward: -6.7, Epsilon: 0.010
# Episode: 720, Total Reward: -1.0, Epsilon: 0.010
# Episode: 721, Total Reward: -6.4, Epsilon: 0.010
# Episode: 722, Total Reward: 4.300000000000001, Epsilon: 0.010
# Episode: 723, Total Reward: -6.5, Epsilon: 0.010
# Episode: 724, Total Reward: 58.69999999999999, Epsilon: 0.010
# Episode: 725, Total Reward: 10.5, Epsilon: 0.010
# Episode: 726, Total Reward: 48.5, Epsilon: 0.010
# Episode: 727, Total Reward: -6.7, Epsilon: 0.010
# Episode: 728, Total Reward: -6.7, Epsilon: 0.010
# Episode: 729, Total Reward: 10.0, Epsilon: 0.010
# Episode: 730, Total Reward: -6.7, Epsilon: 0.010
# Episode: 731, Total Reward: -10, Epsilon: 0.010
# Episode: 732, Total Reward: 22.0, Epsilon: 0.010
# Episode: 733, Total Reward: -7.2, Epsilon: 0.010
# Episode: 734, Total Reward: 63.7, Epsilon: 0.010
# Episode: 735, Total Reward: 26.6, Epsilon: 0.010
# Episode: 736, Total Reward: -1.5, Epsilon: 0.010
# Episode: 737, Total Reward: -10, Epsilon: 0.010
# Episode: 738, Total Reward: 2.1999999999999993, Epsilon: 0.010
# Episode: 739, Total Reward: 39.8, Epsilon: 0.010
# Episode: 740, Total Reward: -3.5, Epsilon: 0.010
# Episode: 741, Total Reward: -7.2, Epsilon: 0.010
# Episode: 742, Total Reward: 19.9, Epsilon: 0.010
# Episode: 743, Total Reward: -10, Epsilon: 0.010
# Episode: 744, Total Reward: -6.5, Epsilon: 0.010
# Episode: 745, Total Reward: -10, Epsilon: 0.010
# Episode: 746, Total Reward: 1.5, Epsilon: 0.010
# Episode: 747, Total Reward: 145.8, Epsilon: 0.010
# Episode: 748, Total Reward: -7.9, Epsilon: 0.010
# Episode: 749, Total Reward: -1.0, Epsilon: 0.010
# Episode: 750, Total Reward: 8.600000000000001, Epsilon: 0.010
# Episode: 751, Total Reward: 4.600000000000001, Epsilon: 0.010
# Episode: 752, Total Reward: -7.8, Epsilon: 0.010
# Episode: 753, Total Reward: 16.3, Epsilon: 0.010
# Episode: 754, Total Reward: 1.5, Epsilon: 0.010
# Episode: 755, Total Reward: -10, Epsilon: 0.010
# Episode: 756, Total Reward: 38.6, Epsilon: 0.010
# Episode: 757, Total Reward: -4.9, Epsilon: 0.010
# Episode: 758, Total Reward: 54.40000000000002, Epsilon: 0.010
# Episode: 759, Total Reward: -10, Epsilon: 0.010
# Episode: 760, Total Reward: -7.9, Epsilon: 0.010
# Episode: 761, Total Reward: -0.9000000000000004, Epsilon: 0.010
# Episode: 762, Total Reward: 4.800000000000001, Epsilon: 0.010
# Episode: 763, Total Reward: 67.39999999999999, Epsilon: 0.010
# Episode: 764, Total Reward: 16.8, Epsilon: 0.010
# Episode: 765, Total Reward: -10, Epsilon: 0.010
# Episode: 766, Total Reward: -1.0, Epsilon: 0.010
# Episode: 767, Total Reward: -7.9, Epsilon: 0.010
# Episode: 768, Total Reward: -0.5, Epsilon: 0.010
# Episode: 769, Total Reward: -2.0, Epsilon: 0.010
# Episode: 770, Total Reward: 2.6999999999999993, Epsilon: 0.010
# Episode: 771, Total Reward: -7.9, Epsilon: 0.010
# Episode: 772, Total Reward: -6.7, Epsilon: 0.010
# Episode: 773, Total Reward: 14.600000000000001, Epsilon: 0.010
# Episode: 774, Total Reward: 11.5, Epsilon: 0.010
# Episode: 775, Total Reward: 18.5, Epsilon: 0.010
# Episode: 776, Total Reward: -5.699999999999999, Epsilon: 0.010
# Episode: 777, Total Reward: -7.9, Epsilon: 0.010
# Episode: 778, Total Reward: 3.8000000000000007, Epsilon: 0.010
# Episode: 779, Total Reward: 101.69999999999999, Epsilon: 0.010
# Episode: 780, Total Reward: 15.400000000000002, Epsilon: 0.010
# Episode: 781, Total Reward: 0.5, Epsilon: 0.010
# Episode: 782, Total Reward: -10, Epsilon: 0.010
# Episode: 783, Total Reward: -1.5999999999999996, Epsilon: 0.010
# Episode: 784, Total Reward: -3.0, Epsilon: 0.010
# Episode: 785, Total Reward: 64.6, Epsilon: 0.010
# Episode: 786, Total Reward: -1.0, Epsilon: 0.010
# Episode: 787, Total Reward: 117.79999999999998, Epsilon: 0.010
# Episode: 788, Total Reward: -10, Epsilon: 0.010
# Episode: 789, Total Reward: 16.6, Epsilon: 0.010
# Episode: 790, Total Reward: 45.6, Epsilon: 0.010
# Episode: 791, Total Reward: -10, Epsilon: 0.010
# Episode: 792, Total Reward: -7.9, Epsilon: 0.010
# Episode: 793, Total Reward: -7.9, Epsilon: 0.010
# Episode: 794, Total Reward: -5.699999999999999, Epsilon: 0.010
# Episode: 795, Total Reward: 41.400000000000006, Epsilon: 0.010
# Episode: 796, Total Reward: 22.299999999999997, Epsilon: 0.010
# Episode: 797, Total Reward: 19.3, Epsilon: 0.010
# Episode: 798, Total Reward: 8.0, Epsilon: 0.010
# Episode: 799, Total Reward: -1.0, Epsilon: 0.010
# Episode: 800, Total Reward: 58.30000000000001, Epsilon: 0.010
# Episode: 801, Total Reward: 44.6, Epsilon: 0.010
# Episode: 802, Total Reward: 71.0, Epsilon: 0.010
# Episode: 803, Total Reward: 1.0999999999999996, Epsilon: 0.010
# Episode: 804, Total Reward: -7.9, Epsilon: 0.010
# Episode: 805, Total Reward: -10, Epsilon: 0.010
# Episode: 806, Total Reward: -1.0, Epsilon: 0.010
# Episode: 807, Total Reward: 18.5, Epsilon: 0.010
# Episode: 808, Total Reward: -7.9, Epsilon: 0.010
# Episode: 809, Total Reward: -10, Epsilon: 0.010
# Episode: 810, Total Reward: 14.3, Epsilon: 0.010
# Episode: 811, Total Reward: -4.3999999999999995, Epsilon: 0.010
# Episode: 812, Total Reward: 4.800000000000001, Epsilon: 0.010
# Episode: 813, Total Reward: -7.9, Epsilon: 0.010
# Episode: 814, Total Reward: 16.2, Epsilon: 0.010
# Episode: 815, Total Reward: -2.0, Epsilon: 0.010
# Episode: 816, Total Reward: -7.9, Epsilon: 0.010
# Episode: 817, Total Reward: 72.0, Epsilon: 0.010
# Episode: 818, Total Reward: -0.9000000000000004, Epsilon: 0.010
# Episode: 819, Total Reward: -10, Epsilon: 0.010
# Episode: 820, Total Reward: 209.8, Epsilon: 0.010
# Episode: 821, Total Reward: -1.0, Epsilon: 0.010
# Episode: 822, Total Reward: 13.100000000000001, Epsilon: 0.010
# Episode: 823, Total Reward: -2.5, Epsilon: 0.010
# Episode: 824, Total Reward: 15.600000000000001, Epsilon: 0.010
# Episode: 825, Total Reward: -1.5, Epsilon: 0.010
# Episode: 826, Total Reward: 47.300000000000004, Epsilon: 0.010
# Episode: 827, Total Reward: -6.7, Epsilon: 0.010
# Episode: 828, Total Reward: 26.0, Epsilon: 0.010
# Episode: 829, Total Reward: -2.0, Epsilon: 0.010
# Episode: 830, Total Reward: 145.79999999999998, Epsilon: 0.010
# Episode: 831, Total Reward: 65.0, Epsilon: 0.010
# Episode: 832, Total Reward: -5.9, Epsilon: 0.010
# Episode: 833, Total Reward: 0.0, Epsilon: 0.010
# Episode: 834, Total Reward: 2.8000000000000007, Epsilon: 0.010
# Episode: 835, Total Reward: 79.39999999999999, Epsilon: 0.010
# Episode: 836, Total Reward: -1.0, Epsilon: 0.010
# Episode: 837, Total Reward: 6.100000000000001, Epsilon: 0.010
# Episode: 838, Total Reward: -4.4, Epsilon: 0.010
# Episode: 839, Total Reward: -10, Epsilon: 0.010
# Episode: 840, Total Reward: -4.0, Epsilon: 0.010
# Episode: 841, Total Reward: -5.4, Epsilon: 0.010
# Episode: 842, Total Reward: 44.0, Epsilon: 0.010
# Episode: 843, Total Reward: 42.4, Epsilon: 0.010
# Episode: 844, Total Reward: 67.10000000000001, Epsilon: 0.010
# Episode: 845, Total Reward: -5.9, Epsilon: 0.010
# Episode: 846, Total Reward: 9.0, Epsilon: 0.010
# Episode: 847, Total Reward: 13.2, Epsilon: 0.010
# Episode: 848, Total Reward: 98.2, Epsilon: 0.010
# Episode: 849, Total Reward: -0.5, Epsilon: 0.010
# Episode: 850, Total Reward: -4.9, Epsilon: 0.010
# Episode: 851, Total Reward: 4.600000000000001, Epsilon: 0.010
# Episode: 852, Total Reward: 10.5, Epsilon: 0.010
# Episode: 853, Total Reward: 39.4, Epsilon: 0.010
# Episode: 854, Total Reward: -4.8999999999999995, Epsilon: 0.010
# Episode: 855, Total Reward: 3.5, Epsilon: 0.010
# Episode: 856, Total Reward: 16.800000000000004, Epsilon: 0.010
# Episode: 857, Total Reward: 13.100000000000001, Epsilon: 0.010
# Episode: 858, Total Reward: -7.9, Epsilon: 0.010
# Episode: 859, Total Reward: 19.799999999999997, Epsilon: 0.010
# Episode: 860, Total Reward: -4.4, Epsilon: 0.010
# Episode: 861, Total Reward: 8.100000000000001, Epsilon: 0.010
# Episode: 862, Total Reward: -7.2, Epsilon: 0.010
# Episode: 863, Total Reward: -1.5999999999999996, Epsilon: 0.010
# Episode: 864, Total Reward: 193.59999999999994, Epsilon: 0.010
# Episode: 865, Total Reward: 21.9, Epsilon: 0.010
# Episode: 866, Total Reward: -7.9, Epsilon: 0.010
# Episode: 867, Total Reward: 5.500000000000002, Epsilon: 0.010
# Episode: 868, Total Reward: 88.30000000000001, Epsilon: 0.010
# Episode: 869, Total Reward: -0.40000000000000036, Epsilon: 0.010
# Episode: 870, Total Reward: 0.5, Epsilon: 0.010
# Episode: 871, Total Reward: 14.2, Epsilon: 0.010
# Episode: 872, Total Reward: -10, Epsilon: 0.010
# Episode: 873, Total Reward: 7.5, Epsilon: 0.010
# Episode: 874, Total Reward: -4.9, Epsilon: 0.010
# Episode: 875, Total Reward: 16.6, Epsilon: 0.010
# Episode: 876, Total Reward: 9.399999999999999, Epsilon: 0.010
# Episode: 877, Total Reward: 11.7, Epsilon: 0.010
# Episode: 878, Total Reward: -10, Epsilon: 0.010
# Episode: 879, Total Reward: 104.00000000000001, Epsilon: 0.010
# Episode: 880, Total Reward: -10, Epsilon: 0.010
# Episode: 881, Total Reward: -7.2, Epsilon: 0.010
# Episode: 882, Total Reward: -4.4, Epsilon: 0.010
# Episode: 883, Total Reward: -7.9, Epsilon: 0.010
# Episode: 884, Total Reward: 22.0, Epsilon: 0.010
# Episode: 885, Total Reward: -7.9, Epsilon: 0.010
# Episode: 886, Total Reward: -10, Epsilon: 0.010
# Episode: 887, Total Reward: -5.699999999999999, Epsilon: 0.010
# Episode: 888, Total Reward: 7.0, Epsilon: 0.010
# Episode: 889, Total Reward: 1.0, Epsilon: 0.010
# Episode: 890, Total Reward: 3.1999999999999993, Epsilon: 0.010
# Episode: 891, Total Reward: 2.5, Epsilon: 0.010
# Episode: 892, Total Reward: -10, Epsilon: 0.010
# Episode: 893, Total Reward: 22.0, Epsilon: 0.010
# Episode: 894, Total Reward: -2.0, Epsilon: 0.010
# Episode: 895, Total Reward: -6.7, Epsilon: 0.010
# Episode: 896, Total Reward: 11.5, Epsilon: 0.010
# Episode: 897, Total Reward: 6.100000000000001, Epsilon: 0.010
# Episode: 898, Total Reward: -6.4, Epsilon: 0.010
# Episode: 899, Total Reward: -5.499999999999999, Epsilon: 0.010
# Episode: 900, Total Reward: 33.6, Epsilon: 0.010
# Episode: 901, Total Reward: -4.4, Epsilon: 0.010
# Episode: 902, Total Reward: 6.899999999999999, Epsilon: 0.010
# Episode: 903, Total Reward: 8.399999999999999, Epsilon: 0.010
# Episode: 904, Total Reward: 29.800000000000004, Epsilon: 0.010
# Episode: 905, Total Reward: -2.0, Epsilon: 0.010
# Episode: 906, Total Reward: 4.100000000000001, Epsilon: 0.010
# Episode: 907, Total Reward: 3.1000000000000014, Epsilon: 0.010
# Episode: 908, Total Reward: 37.5, Epsilon: 0.010
# Episode: 909, Total Reward: 2.3000000000000007, Epsilon: 0.010
# Episode: 910, Total Reward: 5.100000000000001, Epsilon: 0.010
# Episode: 911, Total Reward: 2.3000000000000007, Epsilon: 0.010
# Episode: 912, Total Reward: -10, Epsilon: 0.010
# Episode: 913, Total Reward: 42.5, Epsilon: 0.010
# Episode: 914, Total Reward: 13.500000000000004, Epsilon: 0.010
# Episode: 915, Total Reward: -2.0, Epsilon: 0.010
# Episode: 916, Total Reward: -7.9, Epsilon: 0.010
# Episode: 917, Total Reward: 69.0, Epsilon: 0.010
# Episode: 918, Total Reward: 13.600000000000001, Epsilon: 0.010
# Episode: 919, Total Reward: 16.300000000000004, Epsilon: 0.010
# Episode: 920, Total Reward: -10, Epsilon: 0.010
# Episode: 921, Total Reward: -5.9, Epsilon: 0.010
# Episode: 922, Total Reward: 20.300000000000004, Epsilon: 0.010
# Episode: 923, Total Reward: -3.0, Epsilon: 0.010
# Episode: 924, Total Reward: 0.5, Epsilon: 0.010
# Episode: 925, Total Reward: 19.7, Epsilon: 0.010
# Episode: 926, Total Reward: -5.4, Epsilon: 0.010
# Episode: 927, Total Reward: -10, Epsilon: 0.010
# Episode: 928, Total Reward: 5.000000000000002, Epsilon: 0.010
# Episode: 929, Total Reward: 23.299999999999997, Epsilon: 0.010
# Episode: 930, Total Reward: 104.39999999999999, Epsilon: 0.010
# Episode: 931, Total Reward: -2.5, Epsilon: 0.010
# Episode: 932, Total Reward: -5.9, Epsilon: 0.010
# Episode: 933, Total Reward: -10, Epsilon: 0.010
# Episode: 934, Total Reward: 16.8, Epsilon: 0.010
# Episode: 935, Total Reward: 27.0, Epsilon: 0.010
# Episode: 936, Total Reward: -7.9, Epsilon: 0.010
# Episode: 937, Total Reward: 17.0, Epsilon: 0.010
# Episode: 938, Total Reward: -10, Epsilon: 0.010
# Episode: 939, Total Reward: 20.4, Epsilon: 0.010
# Episode: 940, Total Reward: -10, Epsilon: 0.010
# Episode: 941, Total Reward: 1.0999999999999996, Epsilon: 0.010
# Episode: 942, Total Reward: 43.2, Epsilon: 0.010
# Episode: 943, Total Reward: -7.9, Epsilon: 0.010
# Episode: 944, Total Reward: -2.0, Epsilon: 0.010
# Episode: 945, Total Reward: -4.3999999999999995, Epsilon: 0.010
# Episode: 946, Total Reward: 67.39999999999999, Epsilon: 0.010
# Episode: 947, Total Reward: 6.5, Epsilon: 0.010
# Episode: 948, Total Reward: 48.10000000000001, Epsilon: 0.010
# Episode: 949, Total Reward: -7.9, Epsilon: 0.010
# Episode: 950, Total Reward: 3.3000000000000007, Epsilon: 0.010
# Episode: 951, Total Reward: -5.699999999999999, Epsilon: 0.010
# Episode: 952, Total Reward: 37.0, Epsilon: 0.010
# Episode: 953, Total Reward: -7.8, Epsilon: 0.010
# Episode: 954, Total Reward: 91.30000000000001, Epsilon: 0.010
# Episode: 955, Total Reward: 56.3, Epsilon: 0.010
# Episode: 956, Total Reward: -7.6, Epsilon: 0.010
# Episode: 957, Total Reward: -6.7, Epsilon: 0.010
# Episode: 958, Total Reward: 1.3000000000000007, Epsilon: 0.010
# Episode: 959, Total Reward: 16.6, Epsilon: 0.010
# Episode: 960, Total Reward: 33.0, Epsilon: 0.010
# Episode: 961, Total Reward: -10, Epsilon: 0.010
# Episode: 962, Total Reward: 50.300000000000004, Epsilon: 0.010
# Episode: 963, Total Reward: 4.0, Epsilon: 0.010
# Episode: 964, Total Reward: -2.5, Epsilon: 0.010
# Episode: 965, Total Reward: 0.09999999999999964, Epsilon: 0.010
# Episode: 966, Total Reward: 2.3000000000000007, Epsilon: 0.010
# Episode: 967, Total Reward: -3.3999999999999995, Epsilon: 0.010
# Episode: 968, Total Reward: 78.9, Epsilon: 0.010
# Episode: 969, Total Reward: 1.0999999999999996, Epsilon: 0.010
# Episode: 970, Total Reward: 2.0, Epsilon: 0.010
# Episode: 971, Total Reward: -7.9, Epsilon: 0.010
# Episode: 972, Total Reward: 22.5, Epsilon: 0.010
# Episode: 973, Total Reward: -3.3999999999999995, Epsilon: 0.010
# Episode: 974, Total Reward: 36.900000000000006, Epsilon: 0.010
# Episode: 975, Total Reward: 14.5, Epsilon: 0.010
# Episode: 976, Total Reward: -2.0, Epsilon: 0.010
# Episode: 977, Total Reward: -0.5, Epsilon: 0.010
# Episode: 978, Total Reward: 6.300000000000001, Epsilon: 0.010
# Episode: 979, Total Reward: -0.5999999999999996, Epsilon: 0.010
# Episode: 980, Total Reward: 9.600000000000001, Epsilon: 0.010
# Episode: 981, Total Reward: 27.5, Epsilon: 0.010
# Episode: 982, Total Reward: -0.5, Epsilon: 0.010
# Episode: 983, Total Reward: 10.100000000000001, Epsilon: 0.010
# Episode: 984, Total Reward: 143.9, Epsilon: 0.010
# Episode: 985, Total Reward: 2.0999999999999996, Epsilon: 0.010
# Episode: 986, Total Reward: 43.20000000000001, Epsilon: 0.010
# Episode: 987, Total Reward: 0.5, Epsilon: 0.010
# Episode: 988, Total Reward: 2.6999999999999993, Epsilon: 0.010
# Episode: 989, Total Reward: 7.399999999999999, Epsilon: 0.010
# Episode: 990, Total Reward: -5.9, Epsilon: 0.010
# Episode: 991, Total Reward: 7.399999999999999, Epsilon: 0.010
# Episode: 992, Total Reward: 14.5, Epsilon: 0.010
# Episode: 993, Total Reward: 27.400000000000006, Epsilon: 0.010
# Episode: 994, Total Reward: 19.0, Epsilon: 0.010
# Episode: 995, Total Reward: -2.5, Epsilon: 0.010
# Episode: 996, Total Reward: -3.3999999999999995, Epsilon: 0.010
# Episode: 997, Total Reward: 0.09999999999999964, Epsilon: 0.010
# Episode: 998, Total Reward: -10, Epsilon: 0.010
# Episode: 999, Total Reward: 29.1, Epsilon: 0.010

# %% [markdown]
# Test

# %%
import gymnasium as gym
import torch
import numpy as np
import torch.nn.functional as F
import highway_env
import warnings

warnings.filterwarnings("ignore")

# 測試參數設定
MODEL_PATH = 'models/model.pth'
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 模型定義
class R2D2(torch.nn.Module):
    def __init__(self, input_shape, n_actions):
        super(R2D2, self).__init__()
        self.conv = torch.nn.Sequential(
            torch.nn.Conv2d(4, 32, kernel_size=8, stride=4),
            torch.nn.ReLU(),
            torch.nn.Conv2d(32, 64, kernel_size=4, stride=2),
            torch.nn.ReLU(),
            torch.nn.Conv2d(64, 64, kernel_size=3, stride=1),
            torch.nn.ReLU()
        )
        self.lstm = torch.nn.LSTM(input_size=64 * 7 * 7, hidden_size=512, batch_first=True)
        self.fc = torch.nn.Linear(512, n_actions)

    def forward(self, x, hidden):
        x = x / 255.0
        x = self.conv(x)
        x = x.view(x.size(0), -1)
        x, hidden = self.lstm(x.unsqueeze(0), hidden)
        return self.fc(x.squeeze(0)), hidden

# 加載模型
input_shape = (4, 84, 84)
policy_net = R2D2(input_shape, 5).to(device)
policy_net.load_state_dict(torch.load(MODEL_PATH))
policy_net.eval()

# 測試模型 (至少跑 3 次)
env = gym.make('intersection-v0', render_mode='human')
episodes = 3
for episode in range(episodes):
    state, _ = env.reset()
    done = False
    total_reward = 0

    # 初始化隱藏狀態
    hidden = (torch.zeros(1, 1, 512).to(device), torch.zeros(1, 1, 512).to(device))

    while not done:
        with torch.no_grad():
            # 狀態預處理
            if len(state.shape) == 3:  # (H, W, C)
                state = np.transpose(state, (2, 0, 1))  # (C, H, W)
            elif len(state.shape) == 2:  # (H, W)
                state = np.expand_dims(state, axis=0)  # (1, H, W)

            # 重塑為 (4, 84, 84)
            state = np.tile(state, (4, 1, 1))
            state = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
            state = F.interpolate(state, size=(84, 84), mode='bilinear', align_corners=False)

            # 模型預測動作
            q_values, hidden = policy_net(state, hidden)
            action = q_values.max(1)[1].item()

        # 執行動作
        next_state, reward, done, _, _ = env.step(action)
        state = next_state
        total_reward += reward

    print(f"Episode {episode + 1}: Total Reward = {total_reward}")

env.close()
# Out:
# Episode 1: Total Reward = 9.0
# Episode 2: Total Reward = 9.0
# Episode 3: Total Reward = 0.0
